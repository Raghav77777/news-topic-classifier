# %% [markdown]
# # News Topic Classifier
#
# Fine-tune a BERT model to classify news headlines into topics using labeled data from [NewsData.io](https://newsdata.io). The free `/news` endpoint's `category` field is used as the topic label, so this runs entirely on the **free** tier.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 2. Set your NewsData.io API key
#
# Get a free key at https://newsdata.io. You can also export `NEWSDATA_API_KEY` in your shell instead of setting it here.

# %%
import os
os.environ["NEWSDATA_API_KEY"] = "YOUR_FREE_API_KEY"  # replace with your key

# %% [markdown]
# ## 3. Fetch a labeled dataset

# %%
# !python fetch_data.py --pages 3

# %% [markdown]
# ## 4. Fine-tune the classifier

# %%
# !python train.py --epochs 3

# %% [markdown]
# ## 5. Classify a new headline

# %%
# !python predict.py "Stock markets rally as technology shares surge"
